# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachayar/Todo-sobre-reactores_Vlisp/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U openai-whisper

# %%
# !pip install git+https://github.com/openai/whisper.git

# %%
# !pip install --upgrade --no-deps --force-reinstall git+https://github.com/openai/whisper.git

# %%
# !pip install ffmpeg

# %%
# !whisper Curso4.mp4 -- language English --model medium
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:114: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:04.000]  The following content is provided under a Creative Commons license.
# [00:04.000 --> 00:11.000]  Your support will help MIT OpenCourseWare continue to offer high quality educational resources for free.
# [00:11.000 --> 00:16.000]  To make a donation or view additional materials from hundreds of MIT courses,
# [00:16.000 --> 00:21.000]  visit MIT OpenCourseWare at ocw.mit.edu.
# [00:31.000 --> 00:33.000]  All right, everyone, let's get started.
# [00:33.000 --> 00:37.000]  All right, good afternoon on this rainy, sad afternoon.
# [00:37.000 --> 00:39.000]  So, I'm glad we're inside, though.
# ...
